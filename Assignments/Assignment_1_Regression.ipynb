# %% [markdown]
# # Assignment 1: Regression Analysis
#
# **Course:** Machine Learning S1-2026
# **Total Marks:** 50
# **Due Date:** 20 March 2026, 11:59 PM
#
# ---
#
# ## Student Information
#
# **Student Name:** ________________________
# **Student ID:** __________________________
#
# ---
#
# ## Assignment Overview
#
# In this assignment, you will build an end-to-end regression pipeline to predict IMDB movie scores using the Movies dataset. You will perform exploratory data analysis, preprocess the data (handle missing values, encode categorical features, scale numerical features), and compare multiple regression models: Linear Regression, Polynomial Regression, Ridge Regression, and Lasso Regression. The goal is to evaluate your ability to implement a complete ML pipeline, compare model performances, tune hyperparameters, and provide critical analysis.
#
# ### Submission Format
#
# Submit a single Jupyter Notebook (.ipynb) file containing all code, visualizations, results, and written analysis. Include your name and student ID. Ensure the notebook is well-organized with markdown cells for explanations and code cells for implementation. The notebook should run end-to-end without errors.
#
# ### Dataset: Movies (IMDB Score Prediction)
#
# **Load:** `pd.read_csv('https://raw.githubusercontent.com/danielgrijalva/movie-stats/7c6a562377ab5c91bb80c405be50a0494ae8e582/movies.csv')`
#
# - **Samples:** 7,668 movies
# - **Target:** `score` (IMDB rating, continuous, range 1.9–9.3)
# - **Features to keep:** `genre`, `rating`, `year`, `votes`, `budget`, `runtime`, `country`
# - **Features to drop:** `name`, `director`, `writer`, `star`, `company`, `released`, `gross`
# - **Missing values:** `budget` (~2,171), `runtime` (4), `rating` (77)
# - **Preprocessing needed:** Missing value handling, categorical encoding, feature scaling
#
# ### Instructions
# 1. Complete all TODO sections following the structured approach
# 2. Show all code, outputs, and interpretations
# 3. Use the last 2 digits of your student ID as random seed for reproducibility
# 4. Provide analysis and insights at each step
# 5. Submit the completed notebook with all cells executed
#
# ### Academic Integrity
# This assignment requires original analysis. While you may research concepts, all code, analysis, and conclusions must be your own work.

# %% [markdown]
# ## Setup and Imports
#
# Configure the environment for regression analysis.

# %%
# Essential imports for the analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# Configuration
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (10, 6)
sns.set_style("whitegrid")

# TODO: Replace XX with the last 2 digits of YOUR student ID
STUDENT_SEED = XX  # Example: if your ID ends in 73, use 73; if 00, use 1
np.random.seed(STUDENT_SEED)

# %% [markdown]
# ---
#
# # Part 1: Exploratory Data Analysis & Preprocessing (10 Marks)
#
# Load the Movies dataset, explore its structure, handle missing values, encode categorical features, and prepare the data for regression modelling.

# %%
# Load Movies Dataset
# Source: IMDB Movie Statistics
# Target: score (IMDB rating, 1.9-9.3)

# TODO: Complete the following analysis:

# 1. Load the dataset
movies_df = pd.read_csv('https://raw.githubusercontent.com/danielgrijalva/movie-stats/7c6a562377ab5c91bb80c405be50a0494ae8e582/movies.csv')

# 2. Initial exploration: print shape, dtypes, first 5 rows, statistical summary
#    Use: df.shape, df.dtypes, df.head(), df.describe()

# Your code here:


# 3. Drop columns not needed for prediction: name, director, writer, star, company, released, gross
#    Explain briefly why these columns are dropped

# Your code here:


# 4. Check for missing values: df.isnull().sum()

# Your code here:


# 5. Handle missing values using appropriate imputation (e.g., median for numerical, mode for categorical)
#    Document your choice briefly

# Your code here:


# 6. Visualise distributions:
#    - Target variable 'score': sns.histplot(kde=True), report mean, median, std
#    - Numerical features (year, votes, budget, runtime): histograms or boxplots
#    - Categorical features (genre, rating): value counts or bar plots

# Your code here:


# 7. Correlation analysis:
#    - Compute correlation matrix for numerical features including target
#    - Visualise with sns.heatmap(annot=True)
#    - Which numerical features correlate most strongly with score?

# Your code here:


# 8. Encode categorical features:
#    - Use pd.get_dummies() or OneHotEncoder for 'genre' and 'rating'
#    - For 'country': group countries with fewer than 50 movies into 'Other' before encoding

# Your code here:


# 9. Split data: train_test_split with test_size=0.2, random_state=STUDENT_SEED
#    Then scale numerical features using StandardScaler (fit on train only, transform both)

# Your code here:

# %% [markdown]
# ---
#
# # Part 2: Model Comparison (20 Marks)
#
# Implement and compare four regression approaches: Linear Regression, Polynomial Regression (degrees 2–3), Ridge Regression, and Lasso Regression. Evaluate each model using MSE, RMSE, MAE, and R².

# %%
# TODO: Implement and evaluate the following models:

# --- Model 1: Linear Regression (Baseline) ---
# 1. Fit LinearRegression() on training data and predict on test set
# 2. Evaluate: MSE, RMSE, MAE, R²
# 3. Plot: Predicted vs Actual scatter plot with a diagonal reference line

# Your code here:


# --- Model 2: Polynomial Regression ---
# 1. Use Pipeline with PolynomialFeatures + LinearRegression
# 2. Test degrees 2 and 3 (on numerical features only)
# 3. Evaluate each degree: MSE, RMSE, MAE, R²

# Your code here:


# --- Model 3: Ridge Regression ---
# 1. Test alpha values: [0.01, 0.1, 1.0, 10.0, 100.0]
# 2. Select best alpha based on test R²
# 3. Evaluate best Ridge: MSE, RMSE, MAE, R²

# Your code here:


# --- Model 4: Lasso Regression ---
# 1. Test alpha values: [0.001, 0.01, 0.1, 1.0, 10.0]
# 2. Select best alpha based on test R²
# 3. Evaluate best Lasso: MSE, RMSE, MAE, R²
# 4. How many features does Lasso set to zero?

# Your code here:

# %% [markdown]
# ---
#
# # Part 3: Analysis and Reflection (10 Marks)
#
# Perform feature importance analysis, residual diagnostics, and provide a critical reflection on the modelling process and results.

# %%
# TODO: Complete the following analysis:

# 1. Feature Importance:
#    - Plot the top 10 regression coefficients (by absolute value) from your best model
#    - Which features contribute most to predicting IMDB score?

# Your code here:


# 2. Residual Analysis (for your best model):
#    - Plot residuals vs predicted values
#    - Plot residual distribution (histogram with KDE)

# Your code here:


# 3. Error Analysis:
#    - Identify the 10 movies with the largest prediction errors
#    - What characteristics do these movies share?
#    - Are there genres or time periods where the model performs notably better or worse?

# Your code here:

# %% [markdown]
# ---
#
# # Part 4: Results Summary (10 Marks)

# %% [markdown]
# ## Performance Summary
#
# **TODO: Complete the results table:**
#
# | Model | R² | RMSE | MAE | MSE |
# |-------|-----|------|-----|-----|
# | Linear Regression | | | | |
# | Polynomial (degree=2) | | | | |
# | Polynomial (degree=3) | | | | |
# | Ridge (α=?) | | | | |
# | Lasso (α=?) | | | | |
#
# **Best Model:** [Your answer]
# **Justification:** [Why is this the best model? Consider R², generalization, and complexity]

# %% [markdown]
# ## Reflection
#
# **TODO: Answer the following questions:**
#
# **1.** Which model performed best and why? Was the improvement over the baseline significant?
#
# [Your answer]
#
# **2.** How did your preprocessing choices (missing value handling, encoding, scaling) affect model performance?
#
# [Your answer]
#
# **3.** What are the limitations of predicting IMDB scores using only these features? What additional features might improve the model?
#
# [Your answer]

# %% [markdown]
# ---
#
# # Submission Guidelines
#
# 1. Submit a single Python file or Jupyter notebook (`.ipynb`).
# 2. **File Name Format:**
#    `StudentID_Name_Assignment1.ipynb` **or** `StudentID_Name_Assignment1.py`
# 3. Include all explanatory answers as **comments in the code**.
# 4. Ensure coding answers and plots appear **inline** (if using a notebook) or **saved as files** (if using `.py`).
# 5. Maintain **readable and well-commented code**.
#
# > The `.ipynb` or `.py` file should be uploaded into Moodle through the **Assignment 1 Submission** module (under Assessments, *"Assignment 1 Submission Link"*) before the due date.
#
# ---
#
# ## Instructions for Artificial Intelligence Use
#
# You **may** use Generative AI tools (e.g., ChatGPT, Bard, Grammarly Go) to:
#
# * Clarify concepts, theories, and ideas discussed in class during preparation.
# * Generate preliminary ideas for writing and coding.
# * Edit a working draft of the assessment.
#
# You **may not** use Generative AI to:
#
# * Generate definitions or writing used in your **final submission**.
# * Produce a **paragraph or section of text** for submission.
# * Copy and paste **comments or code** directly into the assignment.
#
# **Important:** Using Generative AI for assessable work may be treated as **third-party assistance** (similar to asking someone else to complete your work). Submitting AI-generated material as your own **without acknowledgement** may be considered **plagiarism** and academic misconduct.
#
# ---
#
# ## Late Submission of Assignments
#
# Assignments submitted late **without an APC (Affected Performance Consideration)** will be penalised:
#
# * **Within 24 hours of the deadline:** 10% deducted
# * **After 24 hours and up to 48 hours:** 20% deducted
# * **Later than 48 hours:** No grade will be awarded
#
# > Assignments more than 48 hours late will **not be marked** unless APC applies. It is always better to submit an **incomplete assignment on time**.
#
# ---
#
# ## Affected Performance Consideration (APC)
#
# If circumstances beyond your control affect your ability to complete an assignment, test, or exam, you should complete the **APC form** available at Student Central or online:
# [https://www.unitec.ac.nz/current-students/study-support/affected-performance-consideration](https://www.unitec.ac.nz/current-students/study-support/affected-performance-consideration)
#
# ---
#
# ## Assistance to Other Students
#
# Helping peers is valuable, but only certain types of assistance are acceptable.
#
# ### Beneficial Assistance
#
# * Study groups
# * Class discussions
# * Sharing reading material
# * Testing another student's program using **executable code** and sharing results
#
# ### Unacceptable Assistance
#
# * Working together on **one copy** of the assessment and submitting it as individual work
# * Giving another student your work
# * Copying another person's work (including from outside the course)
# * Editing or correcting another student's work
# * Copying from books, websites, or the Internet and submitting it as your own
#
# ---
#
# ## Need Help?
#
# To improve your learning and grades, you can:
#
# * Talk with your lecturer
# * Visit **Student Success and Achievement** for support
# * Visit the **Centre for Pacific Development and Support**
# * Visit the **Centre for Māori Development and Support**
