# %% [markdown]
# # Activity A: Data Detective
#
# Investigate the `Students Social Media Addiction` dataset by answering the questions below. Each question requires a short piece of code and a one-line printed answer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.dpi'] = 300
sns.set_style('whitegrid')

# %% [markdown]
# ### Task 1
# Load the dataset and display its shape and first 5 rows.

# %%
df = pd.read_csv('../../../Datasets/Students Social Media Addiction.csv')

# Your code here

# %% [markdown]
# ### Task 2
# Which social media platform has the **highest average addiction score**? Print the platform name and the average score.

# %%
# Your code here

# %% [markdown]
# ### Task 3
# Create a scatter plot of `Avg_Daily_Usage_Hours` vs `Mental_Health_Score`. Add axis labels and a title. What pattern do you observe?

# %%
# Your code here

# %% [markdown]
# ### Task 4
# Compute a correlation matrix for all numeric columns and display it as a heatmap. Which two features have the **strongest correlation** (positive or negative)?

# %%
# Your code here

# %% [markdown]
# ### Task 5
# Compare the **average sleep hours** between students who report that social media affects their academic performance (`Yes`) vs those who do not (`No`). Visualize with a bar chart.

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** Based on your analysis, what is the single most interesting finding in this dataset?
