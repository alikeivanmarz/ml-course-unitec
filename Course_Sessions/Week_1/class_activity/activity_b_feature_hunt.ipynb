# %% [markdown]
# # Activity B: Feature Hunt -- What Drives Wine Quality?
#
# The `winequality-red.csv` dataset contains 11 physicochemical properties of red wine and a quality rating (3-8). Your task: figure out which features matter most for predicting quality.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

plt.rcParams['figure.dpi'] = 300
sns.set_style('whitegrid')
np.random.seed(42)

# %% [markdown]
# ### Task 1
# Load the dataset (separator is `;`) and display its shape and column names.

# %%
df = pd.read_csv('../../../Datasets/winequality-red.csv', sep=';')

# Your code here

# %% [markdown]
# ### Task 2
# Compute the correlation of every feature with `quality`. Sort by absolute value. Which 3 features have the strongest correlation with quality?

# %%
# Your code here

# %% [markdown]
# ### Task 3
# Train a linear regression using **only your top 3 features** to predict `quality`. Report R² and RMSE on the test set.

# %%
# Your code here

# %% [markdown]
# ### Task 4
# Now train a linear regression using **all 11 features**. Report R² and RMSE. Did using all features improve the model?

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** Why might adding more features not always lead to a better model?
