# %% [markdown]
# # Activity C: Salary Predictor
#
# Use the `data_science_salaries.csv` dataset to predict `salary_in_usd` from job features. This activity practices encoding categorical variables and evaluating regression models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

plt.rcParams['figure.dpi'] = 300
np.random.seed(42)

# %% [markdown]
# ### Task 1
# Load the dataset. Display the shape, column names, and data types. How many categorical columns are there?

# %%
df = pd.read_csv('../../../Datasets/data_science_salaries.csv')

# Your code here

# %% [markdown]
# ### Task 2
# Select `experience_level`, `employment_type`, `remote_ratio`, and `company_size` as features. One-hot encode the categorical columns using `pd.get_dummies()` with `drop_first=True`.

# %%
# Your code here

# %% [markdown]
# ### Task 3
# Split the data (80/20), train a `LinearRegression`, and report R² and RMSE on the test set.

# %%
# Your code here

# %% [markdown]
# ### Task 4
# Try adding `work_year` as an additional feature. Does the model improve? Create an actual-vs-predicted scatter plot for your best model.

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** What factors that influence salary might be missing from this dataset?
