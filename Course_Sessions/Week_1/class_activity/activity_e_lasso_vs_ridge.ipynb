# %% [markdown]
# # Activity E: Lasso vs Ridge Showdown
#
# Using the `1000_Companies.csv` dataset with polynomial features, compare how OLS, Ridge, and Lasso handle model complexity differently.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

plt.rcParams['figure.dpi'] = 300
np.random.seed(42)

# %% [markdown]
# ### Task 1
# Load the dataset. Select `R&D Spend`, `Administration`, and `Marketing Spend` as features and `Profit` as the target. Scale the features with `StandardScaler`, then create degree-2 polynomial features.

# %%
df = pd.read_csv('../../../Datasets/1000_Companies.csv')

# Your code here

# %% [markdown]
# ### Task 2
# Split the data (80/20). Train three models: `LinearRegression`, `Ridge(alpha=1.0)`, and `Lasso(alpha=1.0)`. Print the test R² for each.

# %%
# Your code here

# %% [markdown]
# ### Task 3
# Print the coefficients from all three models side by side. How many coefficients did Lasso set to (approximately) zero?

# %%
# Your code here

# %% [markdown]
# ### Task 4
# Use 5-fold cross-validation to find the best `alpha` for Ridge from the list `[0.01, 0.1, 1, 10, 100]`. Print the mean R² for each alpha.

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** When would you choose Lasso over Ridge in practice?
