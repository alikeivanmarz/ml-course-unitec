# %% [markdown]
# # Activity F: Cluster the Students
#
# Use K-Means clustering on the `Students Social Media Addiction` dataset to discover natural groupings among students based on their usage patterns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

plt.rcParams['figure.dpi'] = 300
np.random.seed(42)

# %% [markdown]
# ### Task 1
# Load the dataset. Select `Avg_Daily_Usage_Hours` and `Addicted_Score` as features. Scale them using `StandardScaler`.

# %%
df = pd.read_csv('../../../Datasets/Students Social Media Addiction.csv')

# Your code here

# %% [markdown]
# ### Task 2
# Run K-Means with `k=2`, `k=3`, and `k=4`. For each, create a scatter plot colored by cluster assignment. Use a 1x3 subplot layout.

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

for ax, k in zip(axes, [2, 3, 4]):
    # Your code here
    pass

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3
# Pick the `k` that makes the most sense. Print the **mean values** of each feature for each cluster using `groupby`. Give each cluster a descriptive label (e.g., "light users", "heavy users").

# %%
# Your code here

# %% [markdown]
# ### Task 4 (Bonus)
# Try clustering with a different pair of features (e.g., `Sleep_Hours_Per_Night` and `Mental_Health_Score`). Do the clusters change?

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** Why is scaling important before running K-Means?
