# %% [markdown]
# # Activity G: Pipeline Sprint
#
# Complete a full ML pipeline on the `ENB2012_data.xlsx` building energy dataset. Predict heating load (`Y1`) from the 8 building features (`X1`-`X8`). Five steps, minimal guidance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

plt.rcParams['figure.dpi'] = 300
sns.set_style('whitegrid')
np.random.seed(42)

# %% [markdown]
# ### Step 1: Load and Explore
# Load the dataset. Print its shape, check for missing values, and display `.describe()`.

# %%
# Your code here

# %% [markdown]
# ### Step 2: Visualize
# Create a correlation heatmap of all columns. Which feature has the strongest correlation with `Y1`?

# %%
# Your code here

# %% [markdown]
# ### Step 3: Preprocess
# Select `X1` through `X8` as features and `Y1` as the target. Scale the features. Split into train/test (80/20).

# %%
# Your code here

# %% [markdown]
# ### Step 4: Train and Evaluate
# Train a `LinearRegression`. Report R² and RMSE on the test set.

# %%
# Your code here

# %% [markdown]
# ### Step 5: Diagnose
# Plot actual vs predicted values. Plot the residual distribution. Does the model perform well?

# %%
# Your code here

# %% [markdown]
# ---
# **Reflection:** If the R² is not satisfactory, what would you try next to improve the model?
